# %% [markdown]
# <a href="https://colab.research.google.com/github/abrahamjm01/abrahamjacobo/blob/main/Clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
myList = [1, 2, 4, 'name', 'math.pi', None, True, 2.0, 3/4]

# %%
myList
# Out:
# [1, 2, 4, 'name', 'math.pi', None, True, 2.0, 0.75]

# %%
for iter in myList:
  print(iter, '\t', type(iter))
# Out:
# 1 	 <class 'int'>
# 2 	 <class 'int'>
# 4 	 <class 'int'>
# name 	 <class 'str'>
# math.pi 	 <class 'str'>
# None 	 <class 'NoneType'>
# True 	 <class 'bool'>
# 2.0 	 <class 'float'>
# 0.75 	 <class 'float'>

# %%
len(myList)
# Out:
# 9

# %%
bList = ['f', 'a', 'c', 'd', 'b']

# %%
bList
# Out:
# ['f', 'a', 'c', 'd', 'b']

# %%
print(*bList)
# Out:
# f a c d b

# %%
bList.sort()

# %%
bList
# Out:
# ['a', 'b', 'c', 'd', 'f']

# %%
bList[0]
# Out:
# 'a'

# %%
bList[0:1]
# Out:
# ['a']

# %%
bList[-2]
# Out:
# 'd'

# %%
bList[-2: ]
# Out:
# ['d', 'f']

# %%
path='/content/drive/MyDrive/Cartwheeldata.csv'

# %% [markdown]
# # Sección nueva

# %%
import pandas as pd

# %%
df =pd.read_csv(path)

# %%
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
df.tail(2)
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
x = df.columns

# %%
x = x.to_list()

# %%
x.sort()

# %%
x
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.loc[:5,'ID':'Age']
# Out:
#    ID  Age
# 0   1   56
# 1   2   26
# 2   3   33
# 3   4   39
# 4   5   27
# 5   6   24

# %%
df.loc[:,'ID':'Age']
# Out:
#     ID  Age
# 0    1   56
# 1    2   26
# 2    3   33
# 3    4   39
# 4    5   27
# 5    6   24
# 6    7   28
# 7    8   22
# 8    9   29
# 9   10   33
# 10  11   30
# 11  12   28
# 12  13   25
# 13  14   23
# 14  15   31
# 15  16   26
# 16  17   26
# 17  18   27
# 18  19   23
# 19  20   24
# 20  21   23
# 21  22   29
# 22  23   25
# 23  24   26
# 24  25   23

# %%
df.iloc[:5,0:2]
# Out:
#    ID  Age
# 0   1   56
# 1   2   26
# 2   3   33
# 3   4   39
# 4   5   27

# %%
type(df['CWDistance'])
# Out:
# pandas.core.series.Series

# %%
favs = [ 'Height', 'CWDistance', 'Gender']
df[favs]
# Out:
#     Height  CWDistance Gender
# 0    62.00          79      F
# 1    62.00          70      F
# 2    66.00          85      F
# 3    64.00          87      F
# 4    73.00          72      M
# 5    75.00          81      M
# 6    75.00         107      M
# 7    65.00          98      F
# 8    74.00         106      M
# 9    63.00          65      F
# 10   69.50          96      M
# 11   62.75          79      F
# 12   65.00          92      F
# 13   61.50          66      F
# 14   73.00          72      M
# 15   71.00         115      M
# 16   61.50          90      F
# 17   66.00          74      M
# 18   70.00          64      M
# 19   68.00          85      F
# 20   69.00          66      M
# 21   71.00         101      M
# 22   70.00          82      M
# 23   69.00          63      M
# 24   65.00          67      F

# %%
df.loc[:,favs]
# Out:
#     Height  CWDistance Gender
# 0    62.00          79      F
# 1    62.00          70      F
# 2    66.00          85      F
# 3    64.00          87      F
# 4    73.00          72      M
# 5    75.00          81      M
# 6    75.00         107      M
# 7    65.00          98      F
# 8    74.00         106      M
# 9    63.00          65      F
# 10   69.50          96      M
# 11   62.75          79      F
# 12   65.00          92      F
# 13   61.50          66      F
# 14   73.00          72      M
# 15   71.00         115      M
# 16   61.50          90      F
# 17   66.00          74      M
# 18   70.00          64      M
# 19   68.00          85      F
# 20   69.00          66      M
# 21   71.00         101      M
# 22   70.00          82      M
# 23   69.00          63      M
# 24   65.00          67      F

# %%
df.Gender.unique().size
# Out:
# 2

# %%
df.Score.unique().size
# Out:
# 9

# %%
df.Score.unique()#.size
# Out:
# array([ 7,  8, 10,  4,  3,  9,  5,  6,  2])

# %%
df.groupby(['Gender']).size()
# Out:
# Gender
# F    12
# M    13
# dtype: int64

# %%
df.groupby(['Gender', 'Glasses']).size()
# Out:
# Gender  Glasses
# F       N          4
#         Y          8
# M       N          7
#         Y          6
# dtype: int64

# %%
df[['Gender', 'Glasses']].value_counts()
# Out:
# Gender  Glasses
# F       Y          8
# M       N          7
#         Y          6
# F       N          4
# dtype: int64

# %%
canada='/content/Ejercicios Tarea 1 V2.xlsx'

# %%
df = pd.read_excel(canada,sheet_name='Canada by Citizenship')

# %%
df
# Out:
#               Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    NaN         NaN        NaN        NaN        NaN
# 1                    NaN         NaN        NaN        NaN        NaN
# 2                    NaN         NaN        NaN        NaN        NaN
# 3         United Nations         NaN        NaN        NaN        NaN
# 4    Population Division         NaN        NaN        NaN        NaN
# ..                   ...         ...        ...        ...        ...
# 212           Immigrants  Foreigners      Yemen        935       Asia
# 213           Immigrants  Foreigners     Zambia        903     Africa
# 214           Immigrants  Foreigners   Zimbabwe        903     Africa
# 215           Immigrants  Foreigners    Unknown        999      World
# 216           Immigrants        Both      Total        999      World
#
#     Unnamed: 5      Unnamed: 6 Unnamed: 7          Unnamed: 8  Unnamed: 9  \
# ...
