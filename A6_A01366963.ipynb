# %% [markdown]
# <a href="https://colab.research.google.com/github/abrahamjm01/abrahamjacobo/blob/main/A6_A01366963.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **1. Description of the data set**
#
# This dataset shows the number of kilometers of rail lines in each country from 1995 to 2019.
# The data was not to easy to read and it had columns with codes and others showed years before 1995 without data so I decided to delete them.

# %% [markdown]
# **2.Interesting observations**
#
# When I was taking a look on the data I realized that in 1960 more than 90 countries had rail roads and now in 2019 just 37 of them have rail roads. This surprised me because I used to think that train is a conveyance that helps countries being more connected and bye reading this dataset it's the opposite.

# %%
path= '/content/drive/MyDrive/Rail Road kms.xlsx'

# %%
path
# Out:
# '/content/drive/MyDrive/Rail Road kms.xlsx'

# %%
df=pd.read_excel(path,
                 sheet_name='Data')

# %%
df.head(2)
# Out:
#         Year  Aruba  Africa Eastern and Southern  Afghanistan  \
# 0  Year 1995    NaN                          NaN          NaN
# 1  Year 1996    NaN                          NaN          NaN
#
#    Africa Western and Central  Angola  Albania  Andorra  Arab World  \
# 0                         NaN     NaN    674.0      NaN         NaN
# 1                         NaN     NaN    447.0      NaN         NaN
#
#    United Arab Emirates  ...  Virgin Islands (U.S.)  Vietnam  Vanuatu  World  \
# 0                   NaN  ...                    NaN   2832.0      NaN    NaN
# 1                   NaN  ...                    NaN   2646.0      NaN    NaN
#
#    Samoa  Kosovo  Yemen, Rep.  South Africa  Zambia  Zimbabwe
# 0    NaN     NaN          NaN       21531.0  1273.0       NaN
# 1    NaN     NaN          NaN       22916.0  1273.0       NaN
#
# [2 rows x 267 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df.iloc[:,3:].sum(axis=1)
# Out:
# 0     864549.00000
# 1     875028.00000
# 2     861706.00000
# 3     859284.00000
# 4     869513.00000
# 5     853478.00000
# 6     840673.00000
# 7     838895.00000
# 8     826857.10000
# 9     888304.97500
# 10    805699.49000
# 11    799244.52500
# 12    922413.21400
# 13    816754.76000
# 14    790726.60000
# 15    802061.74201
# 16    788350.07600
# 17    725873.14000
# 18    719907.47600
# 19    702887.03700
# 20    829152.30500
# 21    853662.92100
# 22    846510.38000
# 23    816620.35660
# 24    421204.15229
# dtype: float64

# %% [markdown]
# Then I decided to create a column with the sum of all the km of rail roads per year

# %%
df['Total']=df.iloc[:,3:].sum(axis=1)

# %%
df.head(2)
# Out:
#         Year  Aruba  Africa Eastern and Southern  Afghanistan  \
# 0  Year 1995    NaN                          NaN          NaN
# 1  Year 1996    NaN                          NaN          NaN
#
#    Africa Western and Central  Angola  Albania  Andorra  Arab World  \
# 0                         NaN     NaN    674.0      NaN         NaN
# 1                         NaN     NaN    447.0      NaN         NaN
#
#    United Arab Emirates  ...  Vietnam  Vanuatu  World  Samoa  Kosovo  \
# 0                   NaN  ...   2832.0      NaN    NaN    NaN     NaN
# 1                   NaN  ...   2646.0      NaN    NaN    NaN     NaN
#
#    Yemen, Rep.  South Africa  Zambia  Zimbabwe     Total
# 0          NaN       21531.0  1273.0       NaN  864549.0
# 1          NaN       22916.0  1273.0       NaN  875028.0
#
# [2 rows x 268 columns]

# %% [markdown]
# I had to create and index in order to use the information by year

# %%
df.set_index('Year',inplace=True)

# %%
df.head(2)
# Out:
#            Aruba  Africa Eastern and Southern  Afghanistan  \
# Year
# Year 1995    NaN                          NaN          NaN
# Year 1996    NaN                          NaN          NaN
#
#            Africa Western and Central  Angola  Albania  Andorra  Arab World  \
# Year
# Year 1995                         NaN     NaN    674.0      NaN         NaN
# Year 1996                         NaN     NaN    447.0      NaN         NaN
#
#            United Arab Emirates  Argentina  ...  Vietnam  Vanuatu  World  \
# Year                                        ...
# Year 1995                   NaN        NaN  ...   2832.0      NaN    NaN
# Year 1996                   NaN        NaN  ...   2646.0      NaN    NaN
#
#            Samoa  Kosovo  Yemen, Rep.  South Africa  Zambia  Zimbabwe  \
# Year
# Year 1995    NaN     NaN          NaN       21531.0  1273.0       NaN
# Year 1996    NaN     NaN          NaN       22916.0  1273.0       NaN
#
#               Total
# Year
# Year 1995  864549.0
# ...

# %%
df.loc['Year 1995','Total']
# Out:
# 864549.0

# %%
df.loc[['Year 1995','Year 1996'],'Total']#.plot(kind='line')
# Out:
# Year
# Year 1995    864549.0
# Year 1996    875028.0
# Name: Total, dtype: float64

# %% [markdown]
# To visualize the change in the number of total rail road kms I decided to make a line plot and the I just adjusted the plot size to analyze it easier.

# %%
df.loc[['Year 1995','Year 1996','Year 1997','Year 1998','Year 1999',
        'Year 2000','Year 2001','Year 2002','Year 2003','Year 2004',
        'Year 2005','Year 2006','Year 2007','Year 2008','Year 2009',
        'Year 2010','Year 2011','Year 2012','Year 2013','Year 2014',
        'Year 2015','Year 2016','Year 2017','Year 2018','Year 2019'],
       'Total'].plot(kind='line', figsize=(30,7))

# %% [markdown]
# As we can see in the table above, the number of rail road kms has decreased almost half since 1995. Between 2005 and 2010 we can see a raise in this number but then it decreased, in 2015 it increased again but in 2016 it went down again. This might be because other convenyance are being use more than trains maybe because they´re faster and cheaper.

# %%
Years=['Year 1995','Year 1996','Year 1997','Year 1998','Year 1999',
        'Year 2000','Year 2001','Year 2002','Year 2003','Year 2004',
        'Year 2005','Year 2006','Year 2007','Year 2008','Year 2009',
        'Year 2010','Year 2011','Year 2012','Year 2013','Year 2014',
        'Year 2015','Year 2016','Year 2017','Year 2018','Year 2019']

# %%
Countries=['Mexico','United States']

# %%
x=df.loc[Years,Countries]
x.plot(kind='line')

# %% [markdown]
# As we can see in the table above, the rail road kms in the US is much bigger than the ones we have in Mexico, this might cause a direct impact in the economy and might be a reason for the US to be more devoloped than Mexico.

# %%
favs = [ 'Mexico', 'Canada', 'United States']
df[favs]
# Out:
#             Mexico   Canada  United States
# Year
# Year 1995      NaN      NaN    201284.0000
# Year 1996      NaN      NaN    203875.0000
# Year 1997      NaN      NaN    195804.0000
# Year 1998      NaN      NaN    192815.0000
# Year 1999      NaN      NaN    194708.0000
# Year 2000      NaN      NaN    194077.0000
# Year 2001      NaN      NaN    194746.0000
# Year 2002      NaN      NaN    198057.0000
# Year 2003      NaN      NaN    196806.0000
# Year 2004   7932.0  46543.6    195369.0000
# Year 2005      NaN      NaN    194025.0000
# Year 2006      NaN      NaN    191771.0000
# Year 2007  12035.0  47537.6    193560.5100
# Year 2008      NaN      NaN    192123.0000
# Year 2009      NaN      NaN    191785.0000
# Year 2010      NaN      NaN    194431.0000
# Year 2011      NaN      NaN    194136.0000
# Year 2012      NaN      NaN    153516.6000
# Year 2013      NaN      NaN    154321.5000
# Year 2014  11891.0  58651.0    152932.6000
# Year 2015  11903.0  57264.0    151735.0000
# ...

# %%
df.loc[:,favs]
# Out:
#             Mexico   Canada  United States
# Year
# Year 1995      NaN      NaN    201284.0000
# Year 1996      NaN      NaN    203875.0000
# Year 1997      NaN      NaN    195804.0000
# Year 1998      NaN      NaN    192815.0000
# Year 1999      NaN      NaN    194708.0000
# Year 2000      NaN      NaN    194077.0000
# Year 2001      NaN      NaN    194746.0000
# Year 2002      NaN      NaN    198057.0000
# Year 2003      NaN      NaN    196806.0000
# Year 2004   7932.0  46543.6    195369.0000
# Year 2005      NaN      NaN    194025.0000
# Year 2006      NaN      NaN    191771.0000
# Year 2007  12035.0  47537.6    193560.5100
# Year 2008      NaN      NaN    192123.0000
# Year 2009      NaN      NaN    191785.0000
# Year 2010      NaN      NaN    194431.0000
# Year 2011      NaN      NaN    194136.0000
# Year 2012      NaN      NaN    153516.6000
# Year 2013      NaN      NaN    154321.5000
# Year 2014  11891.0  58651.0    152932.6000
# Year 2015  11903.0  57264.0    151735.0000
# ...

# %% [markdown]
# As we can see in the pivot table above, this data set shows complete information for the US but not for other countries, in this case we have complete information about the US since 1995 but for Mexico and Canada we just have 9 years with data. This could mean that the people that collected the data didn't finish to complete it and with more data the analysis would be better.

# %%
northamerica=df.loc[:,favs]

# %%
northamerica.plot(kind='area',
          stacked=False,
          figsize=(20,10),
          )

# %% [markdown]
# As we can see in the area plot above, the number of rail road kms has no comparison, the US has one of the biggest rail road systems in the world, in second place we have Canada that can't be compared with the US but they have more kms than Mexico.

# %%
df
# Out:
#            Aruba  Africa Eastern and Southern  Afghanistan  \
# Year
# Year 1995    NaN                          NaN          NaN
# Year 1996    NaN                          NaN          NaN
# Year 1997    NaN                          NaN          NaN
# Year 1998    NaN                          NaN          NaN
# Year 1999    NaN                          NaN          NaN
# Year 2000    NaN                          NaN          NaN
# Year 2001    NaN                          NaN          NaN
# Year 2002    NaN                          NaN          NaN
# Year 2003    NaN                          NaN          NaN
# Year 2004    NaN                          NaN          NaN
# Year 2005    NaN                          NaN          NaN
# Year 2006    NaN                          NaN          NaN
# Year 2007    NaN                          NaN          NaN
# Year 2008    NaN                          NaN          NaN
# Year 2009    NaN                          NaN          NaN
# ...

# %%
ndf=df[['United States','China','Japan']]

# %%
from scipy.linalg.matfuncs import transpose
ndf1=transpose(ndf)

# %%
ndf1
# Out:
# Year           Year 1995  Year 1996  Year 1997  Year 1998  Year 1999  \
# United States   201284.0   203875.0   195804.0   192815.0   194708.0
# China            54616.0    56678.0    57566.0    57583.0    57394.0
# Japan            20134.0    20223.0    20243.0    20170.0    29804.0
#
# Year           Year 2000  Year 2001  Year 2002  Year 2003  Year 2004  ...  \
# United States   194077.0   194746.0   198057.0   196806.0   195369.0  ...
# China            58656.0    59079.0    59530.0    60446.0    61015.0  ...
# Japan            29799.0    29809.0    22197.0    20067.3    27591.3  ...
#
# Year           Year 2010  Year 2011  Year 2012  Year 2013  Year 2014  \
# United States   194431.0   194136.0   153516.6   154321.5   152932.6
# China            66239.0    66041.0    66298.0    66585.0    66989.0
# Japan            20140.3    20087.4    19435.4    19435.5    16703.2
#
# Year           Year 2015  Year 2016  Year 2017    Year 2018  Year 2019
# ...
