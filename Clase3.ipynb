# %% [markdown]
# <a href="https://colab.research.google.com/github/abrahamjm01/abrahamjacobo/blob/main/Clase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd.NaT
# Out:
# NaT

# %%
np.nan
# Out:
# nan

# %%
data = {'Company':['Ford','Ford','VW','BMW','Cooper', 'Cooper', pd.NaT],'Stars':[2,1,np.nan,2,2,1,np.nan],'Weight':[2,4,8,4,8,5,np.nan],'Origin':['China','Mexico','China', pd.NaT, 'Mexico', 'China', pd.NaT],'Lenght':[30,40,30,30,50,35,np.nan]}

# %%
type(data)
# Out:
# dict

# %%
print(data)
# Out:
# {'Company': ['Ford', 'Ford', 'VW', 'BMW', 'Cooper', 'Cooper', NaT], 'Stars': [2, 1, nan, 2, 2, 1, nan], 'Weight': [2, 4, 8, 4, 8, 5, nan], 'Origin': ['China', 'Mexico', 'China', NaT, 'Mexico', 'China', NaT], 'Lenght': [30, 40, 30, 30, 50, 35, nan]}

# %%
df= pd.DataFrame(data= data)
df
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    NaN     NaN     NaT     NaN

# %%
df.isnull().sum()
# Out:
# Company    1
# Stars      2
# Weight     1
# Origin     2
# Lenght     1
# dtype: int64

# %%
ndf = df.copy()

# %%
ndf.dropna(inplace= True)

# %%
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0

# %%
df
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    NaN     NaN     NaT     NaN

# %%
ndf= df.copy()

# %%
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    NaN     NaN     NaT     NaN

# %%
ndf.dropna(thresh = 2, inplace = True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0

# %%
ndf.dropna(thresh = 5, inplace = True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0

# %%
ndf=df.copy()

# %%
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    NaN     NaN     NaT     NaN

# %%
ndf.dropna(how='all', inplace=True)

# %%
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0

# %%
ndf.dropna(axis=1,inplace=True)
ndf
# Out:
#   Company  Weight  Lenght
# 0    Ford     2.0    30.0
# 1    Ford     4.0    40.0
# 2      VW     8.0    30.0
# 3     BMW     4.0    30.0
# 4  Cooper     8.0    50.0
# 5  Cooper     5.0    35.0

# %%
ndf=df.copy()
ndf.dropna(how='all',inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0

# %%
ndf=df.copy()
ndf.dropna(how='all',inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    NaN     NaN     NaT     NaN

# %%
print(ndf)
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    NaN     NaN     NaT     NaN

# %%
ndf.dropna(axis=0,inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0

# %%
df.isna()
# Out:
#    Company  Stars  Weight  Origin  Lenght
# 0    False  False   False   False   False
# 1    False  False   False   False   False
# 2    False   True   False   False   False
# 3    False  False   False    True   False
# 4    False  False   False   False   False
# 5    False  False   False   False   False
# 6     True   True    True    True    True

# %%
df.isna().sum()
# Out:
# Company    1
# Stars      2
# Weight     1
# Origin     2
# Lenght     1
# dtype: int64

# %%
df.isna().sum(axis=1)
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# 5    0
# 6    5
# dtype: int64

# %%
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0

# %%
df[df.isna().sum(axis=1)==1]
# Out:
#   Company  Stars  Weight Origin  Lenght
# 2      VW    NaN     8.0  China    30.0
# 3     BMW    2.0     4.0    NaT    30.0

# %%
ndf.Weight.describe()
# Out:
# count    4.00
# mean     4.75
# std      2.50
# min      2.00
# 25%      3.50
# 50%      4.50
# 75%      5.75
# max      8.00
# Name: Weight, dtype: float64

# %%
ndf=df.copy()

# %%
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    NaN     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    NaN     NaN     NaT     NaN

# %%
sm=ndf.Stars.median()

# %%
ndf['Stars'].fillna(value= sm, inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    2.0     8.0   China    30.0
# 3     BMW    2.0     4.0     NaT    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    2.0     NaN     NaT     NaN

# %%
om=ndf.Origin.mode()

# %%
om
# Out:
# 0    China
# dtype: object

# %%
ndf['Origin'].fillna(value= om, inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    2.0     8.0   China    30.0
# 3     BMW    2.0     4.0     NaN    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    2.0     NaN     NaN     NaN

# %%
ndf.dropna(how='all',inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    2.0     8.0   China    30.0
# 3     BMW    2.0     4.0     NaN    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    2.0     NaN     NaN     NaN

# %%
om
# Out:
# 0    China
# dtype: object

# %%
type(om)
# Out:
# pandas.core.series.Series

# %%
om[0]
# Out:
# 'China'

# %%
ndf['Origin'].fillna(value= om[0], inplace=True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    2.0     8.0   China    30.0
# 3     BMW    2.0     4.0   China    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0
# 6     NaT    2.0     NaN   China     NaN

# %%
ndf.dropna(thresh = 3, inplace = True)
ndf
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    2.0     2.0   China    30.0
# 1    Ford    1.0     4.0  Mexico    40.0
# 2      VW    2.0     8.0   China    30.0
# 3     BMW    2.0     4.0   China    30.0
# 4  Cooper    2.0     8.0  Mexico    50.0
# 5  Cooper    1.0     5.0   China    35.0

# %%
pd.pivot_table(index=['Company','Origin'],aggfunc=['median','mean'], data=ndf,values='Stars',margins=True, columns='Lenght')
# Out:
#                median                     mean
# Lenght           30.0 35.0 40.0 50.0  All 30.0 35.0 40.0 50.0       All
# Company Origin
# BMW     China     2.0  NaN  NaN  NaN  2.0  2.0  NaN  NaN  NaN  2.000000
# Cooper  China     NaN  1.0  NaN  NaN  1.0  NaN  1.0  NaN  NaN  1.000000
#         Mexico    NaN  NaN  NaN  2.0  2.0  NaN  NaN  NaN  2.0  2.000000
# Ford    China     2.0  NaN  NaN  NaN  2.0  2.0  NaN  NaN  NaN  2.000000
#         Mexico    NaN  NaN  1.0  NaN  1.0  NaN  NaN  1.0  NaN  1.000000
# VW      China     2.0  NaN  NaN  NaN  2.0  2.0  NaN  NaN  NaN  2.000000
# All               2.0  1.0  1.0  2.0  2.0  2.0  1.0  1.0  2.0  1.666667
